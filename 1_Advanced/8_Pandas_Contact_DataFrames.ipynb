# %% [markdown]
# # .concat()

# %%
# import libraries

import pandas as pd
from datasets import load_dataset
import matplotlib. pyplot as plt

dataset = load_dataset('lukebarousse/data_jobs')
df= dataset['train'].to_pandas()

df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])

# %%
df['job_posted_month'] = df['job_posted_date'].dt.strftime('%b')

# %%
'''
goal: to make fake data to concatenate
 { 'Jan': df_jan,
    'Feb': df_feb,
    'Mar': df_mar,
    ...
 }
'''
df['job_posted_month'] = df['job_posted_date'].dt.strftime('%b')

months = df['job_posted_month'].unique()
months

dict_months = {month: df[df['job_posted_month'] == month ] for month in months}

dict_months['Jan']
# Out:
#           job_title_short  ... job_posted_month
# 1            Data Analyst  ...              Jan
# 20         Data Scientist  ...              Jan
# 39          Data Engineer  ...              Jan
# 53          Data Engineer  ...              Jan
# 55         Data Scientist  ...              Jan
# ...                   ...  ...              ...
# 785699  Software Engineer  ...              Jan
# 785700      Data Engineer  ...              Jan
# 785703       Data Analyst  ...              Jan
# 785704   Business Analyst  ...              Jan
# 785705       Data Analyst  ...              Jan
#
# [91822 rows x 18 columns]

# %% [markdown]
# # Boss needs 2023 Q1

# %%
df_q1 = pd.concat([dict_months['Jan'], dict_months['Feb'], dict_months['Mar']], ignore_index=True)
df_q1
# Out:
#           job_title_short  ... job_posted_month
# 0            Data Analyst  ...              Jan
# 1          Data Scientist  ...              Jan
# 2           Data Engineer  ...              Jan
# 3           Data Engineer  ...              Jan
# 4          Data Scientist  ...              Jan
# ...                   ...  ...              ...
# 220479  Software Engineer  ...              Mar
# 220480       Data Analyst  ...              Mar
# 220481   Business Analyst  ...              Mar
# 220482      Data Engineer  ...              Mar
# 220483  Software Engineer  ...              Mar
#
# [220484 rows x 18 columns]

# %%
df_q1['job_posted_month'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='job_posted_month'>

# %% [markdown]
# # Concat Job Postings

# %%
data_scientist_df  = df[df['job_title_short'] == 'Data Scientist']
data_analyst_df = df[df['job_title_short'] == 'Data Analyst']


combined_df = pd.concat(
    [data_scientist_df,
    data_analyst_df],
    ignore_index=True
)

combined_df
# Out:
#        job_title_short  ... job_posted_month
# 0       Data Scientist  ...              Apr
# 1       Data Scientist  ...              Jun
# 2       Data Scientist  ...              Apr
# 3       Data Scientist  ...              Jan
# 4       Data Scientist  ...              Feb
# ...                ...  ...              ...
# 368356    Data Analyst  ...              Jan
# 368357    Data Analyst  ...              Jan
# 368358    Data Analyst  ...              Mar
# 368359    Data Analyst  ...              Mar
# 368360    Data Analyst  ...              Mar
#
# [368361 rows x 18 columns]

# %% [markdown]
# # Concat Monthly Postings

# %%
df['job_posted_month'] = df['job_posted_date'].dt.strftime('%b')


months = df['job_posted_month'].unique()

dict_months = {month: df[df['job_posted_month'] == month] for month in months}

oct_df = dict_months['Oct']
nov_df = dict_months['Nov']
dec_df = dict_months['Dec']

combined_df = pd.concat([oct_df, nov_df, dec_df], ignore_index=True)

combined_df['job_posted_month'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='job_posted_month'>

# %%
df['job_posted_month'] = df['job_posted_date'].dt.strftime('%b')


months = df['job_posted_month'].unique()

dict_months = {month: df[df['job_posted_month'] == month] for month in months}

oct_df = dict_months['Oct']
nov_df = dict_months['Nov']
dec_df = dict_months['Dec']

combined_df = pd.concat([oct_df, nov_df, dec_df], ignore_index=True)

combined_df['job_posted_month'].value_counts().plot(kind='bar')

# %% [markdown]
# # Concat Job Types

# %%
full_time_df = df[df['job_schedule_type']=='Full-time']

part_time_df = df[df['job_schedule_type']=='Part-time']

combined_df = pd.concat([full_time_df,part_time_df],ignore_index=True)
combined_df
# Out:
#              job_title_short  ... job_posted_month
# 0       Senior Data Engineer  ...              Jun
# 1               Data Analyst  ...              Jan
# 2              Data Engineer  ...              Oct
# 3              Data Engineer  ...              Jul
# 4              Data Engineer  ...              Aug
# ...                      ...  ...              ...
# 709603         Data Engineer  ...              Oct
# 709604  Senior Data Engineer  ...              Oct
# 709605        Data Scientist  ...              Jan
# 709606      Business Analyst  ...              May
# 709607        Data Scientist  ...              Jan
#
# [709608 rows x 18 columns]
